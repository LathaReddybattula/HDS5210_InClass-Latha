# %% [markdown]
# <a href="https://colab.research.google.com/github/LathaReddybattula/HDS5210_InClass-Latha/blob/master/week11/module33-derived-data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
family = pd.DataFrame([
    ['Paul','E','Boal',193,110,'314-598-5494',pd.NA],
    ['Teddy','J','Lester-Boal',101,23,'314-555-1234',25.2],
    ['John','P','Doe',160,100,'490-982-5555',pd.NA]],
    columns=['First','Middle','Last','Height','Weight','Phone','BMI'])

# %%
family
# Out:
#    First Middle         Last  Height  Weight         Phone   BMI
# 0   Paul      E         Boal     193     110  314-598-5494  <NA>
# 1  Teddy      J  Lester-Boal     101      23  314-555-1234  25.2
# 2   John      P          Doe     160     100  490-982-5555  <NA>

# %%
family['Full'] = family.First + ' ' + family.Middle + '. ' + family.Last

# %%
family
# Out:
#    First Middle         Last  Height  Weight         Phone   BMI  \
# 0   Paul      E         Boal     193     110  314-598-5494  <NA>
# 1  Teddy      J  Lester-Boal     101      23  314-555-1234  25.2
# 2   John      P          Doe     160     100  490-982-5555  <NA>
#
#                    Full
# 0          Paul E. Boal
# 1  Teddy J. Lester-Boal
# 2           John P. Doe

# %%
family['Name'] = family.Last + ', ' + family.First + ' ' + family.Middle + '.'

# %%
family
# Out:
#    First Middle         Last  Height  Weight         Phone   BMI  \
# 0   Paul      E         Boal     193     110  314-598-5494  <NA>
# 1  Teddy      J  Lester-Boal     101      23  314-555-1234  25.2
# 2   John      P          Doe     160     100  490-982-5555  <NA>
#
#                    Full                   Name
# 0          Paul E. Boal          Boal, Paul E.
# 1  Teddy J. Lester-Boal  Lester-Boal, Teddy J.
# 2           John P. Doe           Doe, John P.

# %%
family.sort_values('Name')
# Out:
#    First Middle         Last  Height  Weight         Phone   BMI  \
# 0   Paul      E         Boal     193     110  314-598-5494  <NA>
# 2   John      P          Doe     160     100  490-982-5555  <NA>
# 1  Teddy      J  Lester-Boal     101      23  314-555-1234  25.2
#
#                    Full                   Name
# 0          Paul E. Boal          Boal, Paul E.
# 2           John P. Doe           Doe, John P.
# 1  Teddy J. Lester-Boal  Lester-Boal, Teddy J.

# %% [markdown]
# # Splitting

# %%
family['Area Code'] = family.Phone.str.split('-')

# %%
family
# Out:
#    First Middle         Last  Height  Weight         Phone   BMI  \
# 0   Paul      E         Boal     193     110  314-598-5494  <NA>
# 1  Teddy      J  Lester-Boal     101      23  314-555-1234  25.2
# 2   John      P          Doe     160     100  490-982-5555  <NA>
#
#                    Full                   Name         Area Code
# 0          Paul E. Boal          Boal, Paul E.  [314, 598, 5494]
# 1  Teddy J. Lester-Boal  Lester-Boal, Teddy J.  [314, 555, 1234]
# 2           John P. Doe           Doe, John P.  [490, 982, 5555]

# %%
family.Phone.str.split('-',expand=True)
# Out:
#      0    1     2
# 0  314  598  5494
# 1  314  555  1234
# 2  490  982  5555

# %%
family['Area'] = family.Phone.str.split('-',expand=True)[0]

# %%
family['Exchange'] = family.Phone.str.split('-',expand=True)[1]

# %%
family
# Out:
#    First Middle         Last  Height  Weight         Phone   BMI  \
# 0   Paul      E         Boal     193     110  314-598-5494  <NA>
# 1  Teddy      J  Lester-Boal     101      23  314-555-1234  25.2
# 2   John      P          Doe     160     100  490-982-5555  <NA>
#
#                    Full                   Name         Area Code Area Exchange
# 0          Paul E. Boal          Boal, Paul E.  [314, 598, 5494]  314      598
# 1  Teddy J. Lester-Boal  Lester-Boal, Teddy J.  [314, 555, 1234]  314      555
# 2           John P. Doe           Doe, John P.  [490, 982, 5555]  490      982

# %% [markdown]
# # Rank / Percentile

# %%
family.Height.rank()
# Out:
# 0    3.0
# 1    1.0
# 2    2.0
# Name: Height, dtype: float64

# %%
family['Height Rank'] = family.Height.rank()

# %%
family
# Out:
#    First Middle         Last  Height  Weight         Phone   BMI  \
# 0   Paul      E         Boal     193     110  314-598-5494  <NA>
# 1  Teddy      J  Lester-Boal     101      23  314-555-1234  25.2
# 2   John      P          Doe     160     100  490-982-5555  <NA>
#
#                    Full                   Name         Area Code Area  \
# 0          Paul E. Boal          Boal, Paul E.  [314, 598, 5494]  314
# 1  Teddy J. Lester-Boal  Lester-Boal, Teddy J.  [314, 555, 1234]  314
# 2           John P. Doe           Doe, John P.  [490, 982, 5555]  490
#
#   Exchange  Height Rank
# 0      598          3.0
# 1      555          1.0
# 2      982          2.0

# %%
family['Height Pct'] = family.Height.rank(pct=True)

# %%
family
# Out:
#    First Middle         Last  Height  Weight         Phone   BMI  \
# 0   Paul      E         Boal     193     110  314-598-5494  <NA>
# 1  Teddy      J  Lester-Boal     101      23  314-555-1234  25.2
# 2   John      P          Doe     160     100  490-982-5555  <NA>
#
#                    Full                   Name         Area Code Area  \
# 0          Paul E. Boal          Boal, Paul E.  [314, 598, 5494]  314
# 1  Teddy J. Lester-Boal  Lester-Boal, Teddy J.  [314, 555, 1234]  314
# 2           John P. Doe           Doe, John P.  [490, 982, 5555]  490
#
#   Exchange  Height Rank  Height Pct
# 0      598          3.0    1.000000
# 1      555          1.0    0.333333
# 2      982          2.0    0.666667

# %%
family.sort_values('Height Rank')
# Out:
#    First Middle         Last  Height  Weight         Phone   BMI  \
# 1  Teddy      J  Lester-Boal     101      23  314-555-1234  25.2
# 2   John      P          Doe     160     100  490-982-5555  <NA>
# 0   Paul      E         Boal     193     110  314-598-5494  <NA>
#
#                    Full                   Name         Area Code Area  \
# 1  Teddy J. Lester-Boal  Lester-Boal, Teddy J.  [314, 555, 1234]  314
# 2           John P. Doe           Doe, John P.  [490, 982, 5555]  490
# 0          Paul E. Boal          Boal, Paul E.  [314, 598, 5494]  314
#
#   Exchange  Height Rank  Height Pct
# 1      555          1.0    0.333333
# 2      982          2.0    0.666667
# 0      598          3.0    1.000000

# %% [markdown]
# # Arbitrary Functions

# %%
def bmi(x):
    """Series -> float

    vals is a Pandas Series with two elements, Height and Weight
    """
    height = x['Height']
    weight = x['Weight']
    return weight / (height/100)**2

# %%
family[['Height','Weight']].apply(bmi, axis=1)
# Out:
# 0    29.530994
# 1    22.546809
# 2    39.062500
# dtype: float64

# %%
family['BMI'] = family[['Height','Weight']].apply(bmi, axis=1)

# %%
family['BMI'].fillna(family[['Height','Weight']].apply(bmi, axis=1), inplace=True)
# Out:
# <ipython-input-24-28a33bdb1ae1>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   family['BMI'].fillna(family[['Height','Weight']].apply(bmi, axis=1), inplace=True)

# %%
family
# Out:
#    First Middle         Last  Height  Weight         Phone        BMI  \
# 0   Paul      E         Boal     193     110  314-598-5494  29.530994
# 1  Teddy      J  Lester-Boal     101      23  314-555-1234  22.546809
# 2   John      P          Doe     160     100  490-982-5555  39.062500
#
#                    Full                   Name         Area Code Area  \
# 0          Paul E. Boal          Boal, Paul E.  [314, 598, 5494]  314
# 1  Teddy J. Lester-Boal  Lester-Boal, Teddy J.  [314, 555, 1234]  314
# 2           John P. Doe           Doe, John P.  [490, 982, 5555]  490
#
#   Exchange  Height Rank  Height Pct
# 0      598          3.0    1.000000
# 1      555          1.0    0.333333
# 2      982          2.0    0.666667

# %%
family['BMI'].rank()
# Out:
# 0    2.0
# 1    1.0
# 2    3.0
# Name: BMI, dtype: float64

# %%
family
# Out:
#    First Middle         Last  Height  Weight         Phone        BMI  \
# 0   Paul      E         Boal     193     110  314-598-5494  29.530994
# 1  Teddy      J  Lester-Boal     101      23  314-555-1234  22.546809
# 2   John      P          Doe     160     100  490-982-5555  39.062500
#
#                    Full                   Name         Area Code Area  \
# 0          Paul E. Boal          Boal, Paul E.  [314, 598, 5494]  314
# 1  Teddy J. Lester-Boal  Lester-Boal, Teddy J.  [314, 555, 1234]  314
# 2           John P. Doe           Doe, John P.  [490, 982, 5555]  490
#
#   Exchange  Height Rank  Height Pct
# 0      598          3.0    1.000000
# 1      555          1.0    0.333333
# 2      982          2.0    0.666667

# %%
def bmi(height, weight):
    """float, float -> float
    """
    return weight / (height/100)**2

# %%
family.apply(lambda vals: bmi(vals['Height'], vals['Weight']), axis=1)
# Out:
# 0    29.530994
# 1    22.546809
# 2    39.062500
# dtype: float64
